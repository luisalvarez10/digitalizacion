# %% [markdown]
# <a href="https://colab.research.google.com/github/luisalvarez10/digitalizacion/blob/main/ph_agua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def ph_agua():

  #Pedimos al usuario el valor del pH
  while True:
    try:
      ph = float(input("Introduce el pH del agua: "))

      if 0 <= ph <= 14:
        break
      else:
        print("ERROR. INTRODUCE UN VALOR ENTRE 0 Y 14\n")

    except ValueError:
      print("ERROR. INTRODUCE UN VALOR VÁLIDO\n")

  #Calculamos la acidez del agua
  if 0 <= ph <= 4:
    print("Es muy ácido.")

  elif 4 < ph < 7:
    print("Es poco ácido.")

  elif ph == 7:
    print("Es neutro.")

  elif 7 < ph <= 10:
    print("Es poco alcalino")

  elif 10 < ph <= 14:
    print("Es muy alcalino")


ph_agua()
# Out:
# Introduce el pH del agua: dfg
# ERROR. INTRODUCE UN VALOR VÁLIDO
#
# Introduce el pH del agua: 100
# ERROR. INTRODUCE UN VALOR ENTRE 0 Y 14
#
# Introduce el pH del agua: -1
# ERROR. INTRODUCE UN VALOR ENTRE 0 Y 14
#
# Introduce el pH del agua: 12.4
# Es muy alcalino
